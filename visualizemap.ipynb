# %%
import numpy as np
import torch
import torch.nn.functional as F
pooled_map = np.loadtxt('pooled_map.txt')
map = np.loadtxt('map.txt')
print(max(map.flatten()))
print(pooled_map.shape)
print(map.shape)
pooled_map[0,0] = 0
#show map
import matplotlib.pyplot as plt
plt.imshow(map)
plt.show()
plt.imshow(pooled_map)
plt.show()
# Out:
# 96.0
# (26, 20)
# (166, 161)
